# %% [markdown]
# # Train Cycle

# %% [markdown]
# ## import

# %%
import torch
import torch.optim as optim
import os
import math

# %%
print(f"MPS 장치를 지원하도록 build가 되었는가? {torch.backends.mps.is_built()}")
print(f"MPS 장치가 사용 가능한가? {torch.backends.mps.is_available()}")
# Out:
# MPS 장치를 지원하도록 build가 되었는가? True
# MPS 장치가 사용 가능한가? True

# %%
os.chdir('/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files')
from config import *

from enemy_agents import *
from environment import *
from evaluate import *
from file_save_load import *
from mcts import *
from net import *
from train_network import *
from visualizing import *

# %%
print(config)
# Out:
# # Environment
# STATE_SIZE = (9, 9)
# WIN_CONDITION = 5
# F_PATH = /content/drive/MyDrive/Seungyeon/train_files
# F_NAME = 250219-1
#
# ALLOW_TRANSPOSE = True
# DATA_AGUMENTATION = True
#
# # state
# NUM_HISTORY = 3
# PLAYER_INFO = True
#
# # enemy agents
# AB_DEPTH = 100
# MCS_PO_NUM =100
# MCTS_EV_NUM = 100
#
# # net
# ACTION_SIZE = 81
# STATE_DIM = 9
#
# CONV_UNITS = 64
# RESIDUAL_NUM = 8
#
# DEVICE = cpu
#
# # mcts
# C_PUCT = 5
# EVAL_CNT = 400
# TEMPERATURE = 1.0
# TEMPERATURE_DECAY = 0.75
#
# ALPHA = 0.1
# EPSILON = 0.15
#
# # train
# LEARN_RATE = 0.001
# LEARN_DECAY = 0.5
# LEARN_EPOCH = 1000
#
# L2 = 0.0001
# GAMMA = 0.1
# TOTAL_SP_NUM = 1000
# SP_NUM_TRAIN = 1
# EXPLORE_REGULATION = 9
#
# CROSS_ENTROPY = CrossEntropyLoss()
#
# BATCHSIZE = 512
# TRAIN_EPOCHS = 2
# MEM_SIZE = 30000
#
# EPISODES = 1000
#
# # evaluation
# EVAL_NUM_GAME = 20
# TEST_NUM_GAME = 10
# CRITERIA = 0.55
#
# EVAL_FREQUENCY = 20

# %% [markdown]
# ## parameter

# %%
model_type = Net()
env = Environment(STATE_SIZE, WIN_CONDITION)
eval = Evaluate(F_NAME, model_type)
Train = TrainNetwork(F_NAME, model_type)
# Out:
#     Create '250219-1_model_latest.pkl'
#     Create '250219-1_history.pkl'

# %%
Train.train_cycle(eval)
# Out:
# - - - - Episode 1/1000 - - - -
#     Create '250219-1_model_latest.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pz/1m8kjyh1283_znnjwmd3h7740000gn/T/ipykernel_4265/3202581494.py in <module>
# ----> 1 Train.train_cycle(eval)
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/train_network.py in train_cycle(self, eval)
#     205             print(f"- - - - Episode {i+1}/{EPISODES} - - - -")
#     206             self.model = load_model(f'{self.file_name}_model_latest.pkl', self.model_type)
# --> 207             self.save_self_play_history()
#     208             policy_loss_list, value_loss_list, loss_list = self.train_network()
#     209             self.policy_loss_list.extend(policy_loss_list)
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/train_network.py in save_self_play_history(self)
#     114         self_play를 진행하고, file 경로에 history를 저장하는 함수
#     115         '''
# --> 116         data = self._self_play()
#     117
#     118         if DATA_AGUMENTATION:
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/train_network.py in _self_play(self)
#     103
#     104         for _ in range(SP_NUM_TRAIN):
# --> 105             history, n_steps = self._self_play_one_game()
#     106             data.extend(history)
#     107             self.step_list.append(n_steps)
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/train_network.py in _self_play_one_game(self)
#      65             mcts = Mcts(self.model, temperature = self.temp)
#      66
# ---> 67             policies = mcts.get_policy(state) # 가능한 행동들의 확률 분포 얻기
#      68             legal_actions = state.get_legal_actions() # 가능한 행동 (index)
#      69
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/mcts.py in get_policy(self, root_state)
#     133         self.player = root_state.check_first_player() # player 설정
#     134
# --> 135         root_node = Node(root_state, 0, self.model) # root node 생성
#     136
#     137         for _ in range(EVAL_CNT):
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/mcts.py in __init__(self, state, p, model)
#      47         self.model = model
#      48         self.state = state
# ---> 49         self.p = self.add_noise(p) # policy
#      50         self.n = 0 # visit count
#      51         self.w = 0 # cumulative sum of values
#
# ~/Documents/GitHub/24-2-Omok/Seungyeon/mcts.py in add_noise(self, p)
#     109
#     110     def add_noise(self, p):
# --> 111         num_actions = len(p)
#     112         dirichlet_noise = np.random.dirichlet([ALPHA] * num_actions)
#     113         return (1 - EPSILON) * p + EPSILON * dirichlet_noise
#
# TypeError: object of type 'int' has no len()

# %%
env = Environment(STATE_SIZE, WIN_CONDITION)
model = load_model("250219-1_model_latest.pkl")
agent = Mcts(model, 0.0)

is_done = False
n_steps = 0
state = State()

while not is_done:
    n_steps += 1
    env.render(state)
    print("-"*10)

    if n_steps % 2 == 0:
        action = agent.get_action(state)
    else:
        action = int(input("choose action (0~8):"))

    state, is_done, is_lose = env.step(state, action)

reward = env.get_first_reward(state)
print(f"reward of agent: {reward}")
# Out:
#     Load model from '250218-1_model_latest.pkl'
# . . .
# . . .
# . . .
# ----------
# . . .
# . . .
# ○ . .
# ----------
# . . .
# . . .
# ○ ● .
# ----------
# . . .
# ○ . .
# ○ ● .
# ----------
# ● . .
# ○ . .
# ○ ● .
# ----------
# ● . .
# ○ ○ .
# ○ ● .
# ----------
# ● . .
# ○ ○ ●
# ○ ● .
# ----------
# reward of agent: 1
